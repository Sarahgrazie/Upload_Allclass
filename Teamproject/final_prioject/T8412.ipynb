# %%
import requests #이 모듈은 HTTP 요청을 만드는 데 사용됩니다. HTTP/1.1 요청을 보낼 수 있도록 해주며, 주로 웹 API와 상호 작용하기 위해 사용됩니다. HTTP 요청을 보내고 응답을 처리하는 데에 사용됩니다.
import json # 이 모듈은 JSON 데이터를 처리하기 위한 메서드를 제공합니다. JSON은 서버와 웹 애플리케이션 또는 애플리케이션 간에 데이터 교환을 위해 일반적으로 사용되는 경량 데이터 교환 형식입니다.
import pprint #"pretty print"의 약자로, 복잡한 데이터 구조(예: 사전 또는 리스트)를 인간이 읽기 쉬운 형식으로 서식 지정하는 데 사용되는 모듈입니다. 특히 크고 중첩된 데이터 구조를 다룰 때 유용합니다.

# %%
import datetime #날짜와 시간을 다루기 위한 모듈입니다. 날짜 및 시간 관련 함수 및 클래스가 포함되어 있습니다.
import json # JSON 데이터를 다루기 위한 모듈입니다. JSON은 데이터를 효과적으로 표현하고 교환하기 위해 사용되는 형식입니다.
import pytz #시간대(timezone) 관리를 위한 모듈입니다. 시간대 정보를 처리하고 변환하는 데 사용됩니다.
import pandas as pd #데이터 분석과 조작을 위한 라이브러리입니다. 특히, 표 형식의 데이터를 다루는 데 용이합니다.
import numpy as np #과학 및 수학 연산을 위한 라이브러리로, 다차원 배열과 행렬 연산을 지원합니다.
import requests #HTTP 요청을 보내고 응답을 받기 위한 라이브러리입니다. 주로 API와의 상호 작용에 사용됩니다.

import oauth2 as oauth #OAuth 2.0 인증 프로토콜을 구현하기 위한 라이브러리입니다. OAuth는 안전한 및 제한된 액세스를 위한 표준 권한 부여 프레임워크입니다.
from datetime import datetime, timedelta #시간과 관련된 다양한 함수를 제공하는 모듈입니다.
import pytz
import time

# pytz 는 왜 한번 더썻어? 
#주어진 코드는 날짜 및 시간, JSON 데이터, 시간대, 데이터 분석, HTTP 요청 및 OAuth 2.0 인증과 관련된 다양한 기능을 수행할 수 있는 라이브러리와 모듈을 가져오고 있습니다.

# %%
import os
#import os는 Python에서 운영 체제 관련 작업을 수행하기 위한 기본적인 모듈인 os 모듈을 가져오는 코드입니다. 이 모듈은 다양한 운영 체제 기능에 액세스할 수 있는 함수와 메서드를 제공합니다.

# %% [markdown]
# ### API 키 등록하기
# * 개인 api를 발급받으세요.

# %%
APP_KEY = "PSv2mIrp6nU5HIYZgMnu9095iUpxn6QuaOtX"
APP_SECRET = "l9vMRC3ZNtP4JrT0QbXrzlo3IAshmHZl"

#이 코드는 두 개의 문자열 변수 APP_KEY와 APP_SECRET를 정의하고 있습니다. 이러한 변수들은 아마도 어떤 애플리케이션이나 서비스를 사용하기 위한 인증 정보일 것입니다.

#보통 이러한 키와 시크릿은 외부 API 또는 서비스와의 통신을 할 때 사용됩니다.

# %% [markdown]
# ### 접근 토큰 발급받기
# * 하루에 한번씩 받아야합니다.

# %%
def access_token(APP_KEY,APP_SECRET):
    header = {"content-type":"application/x-www-form-urlencoded"}
    param = {"grant_type":"client_credentials",
            "appkey":APP_KEY,
            "appsecretkey":APP_SECRET,
            "scope":"oob"
            }
    PATH = "oauth2/token"
    BASE_URL = "https://openapi.ebestsec.co.kr:8080"
    URL = f"{BASE_URL}/{PATH}"

    request = requests.post(URL, verify=False, headers=header, params=param ,timeout=3)

    if __name__ == "__main__":
        print("URL          : ", URL, "\n")               
        print("OAuth        : ")
        pprint.pprint(request.json()) 
    
    ACCESS_TOKEN = request.json()["access_token"] 

    return ACCESS_TOKEN

# %%
acc_token=access_token(APP_KEY,APP_SECRET)  #토큰 발급 실행
acc_token
# Out:
# URL          :  https://openapi.ebestsec.co.kr:8080/oauth2/token
#
# OAuth        :
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..ICl-Mjs3UTj2HoQiVyLNpQBFNT5y6vUC9ex2PJjB8SS79lEe9N0-AuoYnytMd1Dy67_Ffn-DM5I_b6W8YI_EVA',
#  'expires_in': 44735,
#  'scope': 'oob',
#  'token_type': 'Bearer'}
# c:\ProgramData\anaconda3\envs\ml-dev\lib\site-packages\urllib3\connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'openapi.ebestsec.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..ICl-Mjs3UTj2HoQiVyLNpQBFNT5y6vUC9ex2PJjB8SS79lEe9N0-AuoYnytMd1Dy67_Ffn-DM5I_b6W8YI_EVA'

# %%
class t8412:
    def t8412(shcode = None, todt = "", period = 364) :
        """
        eBest Open API에서 t1716 TR을 호출하기 위한 URL, 헤더 및 바디 정보를 반환하는 함수입니다.

        Parameters:
            shcode (str, optional)  : 종목코드를 지정하는 매개변수입니다.
            todt (str, optional)    : 조회를 종료할 날짜를 지정하는 매개변수입니다. 기본값은 오늘 날짜로 설정됩니다.
            period (int, optional)  : 조회 기간을 지정하는 매개변수입니다. 기본값은 365일(1년)입니다.

        Returns:
            tuple                   : url, 헤더, 바디 정보, 함수 이름, 반환 데이터 태그, 종목코드를 포함하는 튜플을 반환합니다.
        """

        _url_base   = "https://openapi.ebestsec.co.kr:8080"
        _path       = "stock/chart"
        _url        = f"{_url_base}/{_path}"

        _header     = {
            "content-type"  : "application/json; charset=UTF-8",
            "authorization" : acc_token,                             # fill in RunTR()
            "tr_cd"         : "t8412",
            "tr_cont"       : "N",
            "tr_cont_key"   : "",
            "mac_address"   : ""
        }

        # 시작일자와 종료일자를 YYYYMMDD 형식으로 생성하기
        #오늘날짜 구하기(종료일)
        _seoul_timezone = pytz.timezone('Asia/Seoul')
        _seoul_dt       = datetime.now(_seoul_timezone)
        _todt           = _seoul_dt.strftime('%Y%m%d') if todt == "" else todt
        #1년전 구하기(시작일)
        _todt_datetime = datetime.strptime(_todt, '%Y%m%d').astimezone(_seoul_timezone)
        _fromdt = (_todt_datetime - timedelta(period)).strftime("%Y%m%d")
          
        print(_todt)
        print(_fromdt)
        _body           ={
            "t8412InBlock" : {
                "shcode" : shcode ,             #종목코드 String
                "ncnt" : 1,                     #단위(n분) Number
                "qrycnt" : 500,                  #요청건수(최대-압축:2000 비압축 :500) Number
                "nday" : "5",                   #조회영업일수(0:미사용 1>=사용) String
                "sdate" : _fromdt,              #시작일자   String
                "stime" : "090000",             #시작시간(현재미사용)   String
                "edate" : _todt,                #종료일자   String
                "etime" : "153000",             #종료시간(현재미사용)   String
                "cts_date" : "1",               #연속일자   String
                "cts_time" : "1",               #연속시간   String
                "comp_yn" : "N"                 #압축여부(Y:압축N:비압축)   String
            }
        }

        _out_block_tag = "OutBlock"

        return _url, _header, _body, t8412.t8412.__name__, _out_block_tag, shcode

# %%
if __name__ == "__main__":

    url, header, body, tr_name, out_block_tag, shcode_ = t8412.t8412()
    
    print("URL              :")
    pprint.pprint(url)
    print("\nheader           :")
    pprint.pprint(header)
    print("\nbody             :")
    pprint.pprint(body)
    print("\ntr name          :")
    pprint.pprint(tr_name)
    print("\nOutBlockTag      :")
    pprint.pprint(out_block_tag)
    print("\nshcode           :")
    pprint.pprint(shcode_)
# Out:
# 20240102
# 20230103
# URL              :
# 'https://openapi.ebestsec.co.kr:8080/stock/chart'
#
# header           :
# {'authorization': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..ICl-Mjs3UTj2HoQiVyLNpQBFNT5y6vUC9ex2PJjB8SS79lEe9N0-AuoYnytMd1Dy67_Ffn-DM5I_b6W8YI_EVA',
#  'content-type': 'application/json; charset=UTF-8',
#  'mac_address': '',
#  'tr_cd': 't8412',
#  'tr_cont': 'N',
#  'tr_cont_key': ''}
#
# body             :
# {'t8412InBlock': {'comp_yn': 'N',
#                   'cts_date': '1',
#                   'cts_time': '1',
#                   'edate': '20240102',
#                   'etime': '153000',
#                   'ncnt': 1,
#                   'nday': '5',
#                   'qrycnt': 500,
#                   'sdate': '20230103',
#                   'shcode': None,
#                   'stime': '090000'}}
#
# tr name          :
# 't8412'
#
# OutBlockTag      :
# 'OutBlock'
#
# shcode           :
# None

# %%
def request_tr(url, header, body, tr_name, out_block_tag, shcode,ACCESS_TOKEN):
    """
    eBest Open API에서 TR을 호출하여 데이터를 조회하는 함수입니다.

    Parameters:
        url (str)           : API 호출을 위한 URL입니다.
        header (dict)       : API 호출에 필요한 헤더 정보가 담긴 딕셔너리입니다.
        body (dict)         : API 호출에 필요한 바디 정보가 담긴 딕셔너리입니다.
        tr_name (str)       : 함수 이름입니다.
        out_block_tag (str) : 반환 데이터의 태그입니다.
        shcode (str)        : 종목코드를 지정하는 매개변수입니다.
        ACCESS_TOKEN (str)  : access_token(APP_KEY,APP_SECRET)메소드로 반한된 접근 토큰입니다.
    Returns:
        pandas.DataFrame    : 조회된 데이터가 담긴 DataFrame 객체를 반환합니다.
        str                 : 함수 이름을 반환합니다.
        str                 : 종목코드를 반환합니다.
    """

    header["authorization"] = f"Bearer {ACCESS_TOKEN}"
    _res = requests.post(url, headers=header, data=json.dumps(body), timeout=3.2)   #지정된 시간내에 응답이 오지 않으면 예외가 발생하므로 try/except 구문설정하기
    _json_data = _res.json()
    print(_json_data)                                                          # Ok
    print(f"{tr_name}{out_block_tag}1")                                        # Ok
    _data_frame = pd.json_normalize(_json_data[f"{tr_name}{out_block_tag}1"])    #json양식을 데이터 프레임으로 바꾸기

    return _data_frame, tr_name, shcode

# %%
def save_csv(data_frame, tr_name, shcode=""):
    """
    조회된 데이터를 CSV 파일로 저장하는 함수입니다.

    Parameters:
        data_frame (pandas.DataFrame) : 조회된 데이터가 담긴 DataFrame 객체입니다.
        tr_name (str)                 : 저장할 파일의 이름을 지정하는 매개변수입니다.
        shcode (str, optional)        : 종목코드를 지정하는 매개변수입니다. 기본값은 ""(빈 문자열)입니다.

    Returns:
        None
    """

    _seoul_timezone = pytz.timezone('Asia/Seoul')
    _time_stamp = datetime.now(_seoul_timezone).strftime("%Y%m%d_%H%M%S")
    if len(shcode) > 0:
        _path = f'./{tr_name.upper()}_{shcode}_{_time_stamp}.csv'
    else:
        _path = f'./{tr_name.upper()}_{_time_stamp}.csv'
    data_frame.to_csv(_path)
    print("파일 저장을 완료하였습니다. :", _path)

# %%
if __name__ == "__main__":
    # df=pd.read_csv('./6.csv')
    # codes=df.iloc[:200,]['종목코드'].to_list()
        code="005940"
    # for code in codes:
        results, tr_name, shcode = request_tr(*t8412.t8412(shcode=code, period=365),ACCESS_TOKEN=acc_token)             # 삼성전자, 1년치 일일 데이터
        print(results)
        
        save_csv(results, tr_name, shcode)
        #time.sleep(3.2)
# Out:
# 20240102
# 20230102
# {'t8412OutBlock': {'shcode': '005940', 'jisiga': 10210, 'jihigh': 10330, 'jilow': 10110, 'jiclose': 10330, 'jivolume': 712436, 'disiga': 10250, 'dihigh': 10280, 'dilow': 10090, 'diclose': 10160, 'highend': 13420, 'lowend': 7240, 'cts_date': '20231228', 'cts_time': '122200', 's_time': '100000', 'e_time': '153000', 'dshmin': '10', 'rec_count': 500}, 't8412OutBlock1': [{'date': '20231228', 'time': '122300', 'open': 10230, 'high': 10240, 'low': 10230, 'close': 10240, 'jdiff_vol': 552, 'value': 6, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '122400', 'open': 10240, 'high': 10240, 'low': 10230, 'close': 10240, 'jdiff_vol': 685, 'value': 7, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '122500', 'open': 10240, 'high': 10240, 'low': 10230, 'close': 10230, 'jdiff_vol': 659, 'value': 7, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '122600', 'open': 10230, 'high': 10240, 'low': 10230, 'close': 10240, 'jdiff_vol': 652, 'value': 7, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '122700', 'open': 10230, 'high': 10240, 'low': 10220, 'close': 10220, 'jdiff_vol': 1957, 'value': 20, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '122800', 'open': 10220, 'high': 10230, 'low': 10220, 'close': 10220, 'jdiff_vol': 634, 'value': 6, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '122900', 'open': 10220, 'high': 10230, 'low': 10210, 'close': 10210, 'jdiff_vol': 435, 'value': 4, 'jongchk': 0, 'rate': '0.00', 'sign': '3'}, {'date': '20231228', 'time': '123000', 'open': 10220, 'high': 10230, 'low': 10220, 'close': 10220, 'jdiff_vol': 260, 'value': 3, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '123100', 'open': 10220, 'high': 10230, 'low': 10210, 'close': 10210, 'jdiff_vol': 528, 'value': 5, 'jongchk': 0, 'rate': '0.00', 'sign': '3'}, {'date': '20231228', 'time': '123200', 'open': 10220, 'high': 10220, 'low': 10210, 'close': 10220, 'jdiff_vol': 884, 'value': 9, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '123300', 'open': 10220, 'high': 10220, 'low': 10210, 'close': 10210, 'jdiff_vol': 424, 'value': 4, 'jongchk': 0, 'rate': '0.00', 'sign': '3'}, {'date': '20231228', 'time': '123400', 'open': 10210, 'high': 10230, 'low': 10210, 'close': 10220, 'jdiff_vol': 1122, 'value': 11, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '123500', 'open': 10220, 'high': 10230, 'low': 10220, 'close': 10220, 'jdiff_vol': 407, 'value': 4, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '123600', 'open': 10220, 'high': 10230, 'low': 10220, 'close': 10230, 'jdiff_vol': 450, 'value': 5, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '123700', 'open': 10220, 'high': 10230, 'low': 10220, 'close': 10230, 'jdiff_vol': 994, 'value': 10, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '123800', 'open': 10220, 'high': 10230, 'low': 10220, 'close': 10230, 'jdiff_vol': 416, 'value': 4, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '123900', 'open': 10230, 'high': 10230, 'low': 10220, 'close': 10230, 'jdiff_vol': 94, 'value': 1, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '124000', 'open': 10230, 'high': 10230, 'low': 10210, 'close': 10210, 'jdiff_vol': 2006, 'value': 21, 'jongchk': 0, 'rate': '0.00', 'sign': '3'}, {'date': '20231228', 'time': '124100', 'open': 10220, 'high': 10230, 'low': 10210, 'close': 10230, 'jdiff_vol': 1819, 'value': 19, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '124200', 'open': 10220, 'high': 10230, 'low': 10220, 'close': 10220, 'jdiff_vol': 844, 'value': 9, 'jongchk': 0, 'rate': '0.00', 'sign': '2'}, {'date': '20231228', 'time': '124300', 'open': 10220, 'high': 10220, 'low': 10210, 'close': 10220, 'jdiff_vol': 527, 'value': 5, 'jongchk': 0, 'rate': '0.00', 'sig ...
# t8412OutBlock1
#          date    time   open   high    low  close  jdiff_vol  value  jongchk  \
# 0    20231228  122300  10230  10240  10230  10240        552      6        0
# 1    20231228  122400  10240  10240  10230  10240        685      7        0
# 2    20231228  122500  10240  10240  10230  10230        659      7        0
# 3    20231228  122600  10230  10240  10230  10240        652      7        0
# 4    20231228  122700  10230  10240  10220  10220       1957     20        0
# ..        ...     ...    ...    ...    ...    ...        ...    ...      ...
# 495  20240102  151700  10170  10180  10170  10170       2777     28        0
# 496  20240102  151800  10180  10180  10160  10160        471      5        0
# 497  20240102  151900  10170  10170  10160  10160         42      0        0
# 498  20240102  152000  10170  10170  10160  10170        812      8        0
# 499  20240102  153000  10160  10160  10160  10160      57637    586        0
#
#      rate sign
# 0    0.00    2
# 1    0.00    2
# 2    0.00    2
# 3    0.00    2
# 4    0.00    2
# ..    ...  ...
# 495     0    5
# 496     0    5
# 497     0    5
# 498     0    5
# 499     0    5
#
# [500 rows x 11 columns]
# 파일 저장을 완료하였습니다. : ./T8412_005940_20240102_183426.csv
